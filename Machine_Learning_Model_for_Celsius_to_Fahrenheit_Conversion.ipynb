# %% [markdown]
# <a href="https://colab.research.google.com/github/Teraces12/LebedeNgartera/blob/main/Machine_Learning_Model_for_Celsius_to_Fahrenheit_Conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**MACHINE LEARNING MODEL TO CONVERT FROM CELSIUS TO FAHRENHEIT**
# ![Screenshot 2023-11-21 130507.png](data:image/png;base64,...)

# %% [markdown]
# ##**I) INTRODUCTION:**
# This project focuses on the development of a machine learning model designed to convert temperatures from Celsius to Fahrenheit. While the Celsius to Fahrenheit conversion is a simple mathematical formula, the objective here is to leverage machine learning techniques to create a predictive model that can generalize well to a wide range of input data. This approach opens up possibilities for handling complex patterns and non-linear relationships that may exist in temperature data.

# %% [markdown]
# #**II) OBJECTIVE:**
# The primary goal of this project is to create an accurate and robust machine learning model capable of converting Celsius temperatures to Fahrenheit. The model should be able to generalize well to different input ranges and handle variations in temperature patterns. The project aims to explore various machine learning algorithms, feature engineering techniques, and model evaluation metrics to achieve optimal performance.

# %% [markdown]
# ##**III) PROJECT STATEMENT**

# %% [markdown]
# 1. We are going to build a machine learning model to convert from celsius to
# fahrenheit.
# 2. The equation is as follows: **T(°F) = T(°C) × 9/5 + 32**
# 3. For Example, let's convert 0°C celsius temperature to Fahrenheit:  **(0°C × 9/5) + 32 = 32°F**

# %% [markdown]
# <table>
#   <tr><td>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/7/70/Thermometer_CF.svg"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure . Convert Celsius to Fahrenheit [Image Source: https://commons.wikimedia.org/wiki/File:Thermometer_CF.svg]
#   </td></tr>
# </table>

# %% [markdown]
# ##**IV) IMPORT LIBRARIES**

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##**V)IMPORT DATASETS**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Temp_df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Celsius+to+Fahrenheit.csv')
Temp_df.reset_index(drop=True, inplace=True)

# %%
Temp_df
# Out:
#     Celsius  Fahrenheit
# 0       -50       -58.0
# 1       -40       -40.0
# 2       -30       -22.0
# 3       -20        -4.0
# 4       -10        14.0
# 5        -9        15.8
# 6        -8        17.6
# 7        -7        19.4
# 8        -6        21.2
# 9        -5        23.0
# 10       -4        24.8
# 11       -3        26.6
# 12       -2        28.4
# 13       -1        30.2
# 14        0        32.0
# 15        1        33.8
# 16        2        35.6
# 17        3        37.4
# 18        4        39.2
# 19        5        41.0
# 20        6        42.8
# 21        7        44.6
# 22        8        46.4
# 23        9        48.2
# 24       10        50.0
# 25       20        68.0
# 26       30        86.0
# 27       40       104.0
# 28       50       122.0
# 29       60       140.0

# %%
Temp_df.head(5)
# Out:
#    Celsius  Fahrenheit
# 0      -50       -58.0
# 1      -40       -40.0
# 2      -30       -22.0
# 3      -20        -4.0
# 4      -10        14.0

# %%
Temp_df.tail(10)
# Out:
#     Celsius  Fahrenheit
# 20        6        42.8
# 21        7        44.6
# 22        8        46.4
# 23        9        48.2
# 24       10        50.0
# 25       20        68.0
# 26       30        86.0
# 27       40       104.0
# 28       50       122.0
# 29       60       140.0

# %%
Temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Celsius     30 non-null     int64
#  1   Fahrenheit  30 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes

# %%
Temp_df.describe()
# Out:
#          Celsius  Fahrenheit
# count  30.000000   30.000000
# mean    2.000000   35.600000
# std    22.780815   41.005466
# min   -50.000000  -58.000000
# 25%    -6.750000   19.850000
# 50%     0.500000   32.900000
# 75%     7.750000   45.950000
# max    60.000000  140.000000

# %% [markdown]
# #**VI) DATASET VISUALIZATION**
#
# ---

# %%
plt.scatter(Temp_df['Celsius'], Temp_df['Fahrenheit'],color='coral')

# %% [markdown]
# ##**VII) *CREATE* TESTING AND TRAINING DATASET**

# %%
X_train = Temp_df['Celsius']
y_train = Temp_df['Fahrenheit']

# %% [markdown]
# ```
#
# ##**VIII) BUILD AND TRAIN THE MODEL**

# %%
X_train.shape
# Out:
# (30,)

# %%
y_train.shape
# Out:
# (30,)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1, input_shape=[1]))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.5), loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 465ms/step - loss: 5858.3042
# Epoch 2/100
# 1/1 [==============================] - 0s 11ms/step - loss: 4383.2300
# Epoch 3/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3172.4829
# Epoch 4/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2226.5505
# Epoch 5/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1539.3741
# Epoch 6/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1095.6078
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 867.9724
# Epoch 8/100
# 1/1 [==============================] - 0s 8ms/step - loss: 815.8156
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 886.7018
# Epoch 10/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1022.3036
# Epoch 11/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1167.6464
# Epoch 12/100
# ...

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1), loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 354ms/step - loss: 1.8133
# Epoch 2/500
# 1/1 [==============================] - 0s 15ms/step - loss: 496.6077
# Epoch 3/500
# 1/1 [==============================] - 0s 10ms/step - loss: 33.1143
# Epoch 4/500
# 1/1 [==============================] - 0s 8ms/step - loss: 105.1522
# Epoch 5/500
# 1/1 [==============================] - 0s 12ms/step - loss: 283.7281
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 213.9427
# Epoch 7/500
# 1/1 [==============================] - 0s 12ms/step - loss: 61.0146
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7950
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 62.8721
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 135.6965
# Epoch 11/500
# 1/1 [==============================] - 0s 14ms/step - loss: 130.0356
# Epoch 12/500
# ...

# %% [markdown]
# ##**IX) EVALUATING THE MODEL**

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss'])

# %%
plt.plot(epochs_hist.history['loss'],color='coral')

# %%
plt.plot(epochs_hist.history['loss'],color='b')
plt.title('Model Loss Progress During Training')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.legend(['Training Loss'])

# %%
model.get_weights()
# Out:
# [array([[1.8000001]], dtype=float32), array([32.], dtype=float32)]

# %% [markdown]
# Use the trained model to perform predictions

# %%
Temp_C = 0
Temp_F = model.predict([Temp_C])
print('Temperature in degF Using Trained ANN =', Temp_F)
# Out:
# 1/1 [==============================] - 0s 92ms/step
# Temperature in degF Using Trained ANN = [[32.]]

# %% [markdown]
# Let's confirm with the equation

# %%
Temp_F= 9/5*Temp_C + 32
print('Temperature in DegreF using Equation =', Temp_F)
# Out:
# Temperature in DegreF using Equation = 32.0

# %% [markdown]
# Let's confirm this Using the equation:

# %%
Temp_F = 9/5 * Temp_C + 32
print('Temperature in degF Using Equation =', Temp_F)
# Out:
# Temperature in degF Using Equation = 32.0

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/lebede-ngartera-82429343?lipi=urn%3Ali%3Apage%3Ad_flagship3_profile_view_base_contact_details%3BI8f5HtANSiWQt%2B1jRbg1pQ%3D%3D"> Dr Lebede Ngartera</a>
